# %%
import os as os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Documents'

# %%
os.chdir('C:\\Users\\Admin\\Downloads\\mortDefault')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Downloads\\mortDefault'

# %%
import pandas as pd

# %%
mortdefault2000 = pd.read_csv('mortDefault2000.csv')

# %%
filelist=os.listdir()

# %%
filelist
# Out:
# ['mortDefault2000.csv',
#  'mortDefault2001.csv',
#  'mortDefault2002.csv',
#  'mortDefault2003.csv',
#  'mortDefault2004.csv',
#  'mortDefault2005.csv',
#  'mortDefault2006.csv',
#  'mortDefault2007.csv',
#  'mortDefault2008.csv',
#  'mortDefault2009.csv']

# %%
mortdefault = [pd.read_csv(i) for i in filelist]

# %%
mortdefault
# Out:
# [        creditScore  houseAge  yearsEmploy  ccDebt  year  default
#  0               615        10            5    2818  2000        0
#  1               780        34            5    3575  2000        0
#  2               735        12            1    3184  2000        0
#  3               713        15            5    6236  2000        0
#  4               689        10            5    6817  2000        0
#  5               713        13            3    3646  2000        0
#  6               749        30            7    8056  2000        0
#  7               738        21            6    5611  2000        0
#  8               745        13            5    4780  2000        0
#  9               762        15            9    6161  2000        0
#  10              707         5            3    4992  2000        0
#  11              621        15            6    7427  2000        0
#  12              649        14            3    3573  2000        0
# ...

# %%
mortdefault2000 = pd.read_csv('mortDefault2000.csv')

# %%
mortdefault2000
# Out:
#         creditScore  houseAge  yearsEmploy  ccDebt  year  default
# 0               615        10            5    2818  2000        0
# 1               780        34            5    3575  2000        0
# 2               735        12            1    3184  2000        0
# 3               713        15            5    6236  2000        0
# 4               689        10            5    6817  2000        0
# 5               713        13            3    3646  2000        0
# 6               749        30            7    8056  2000        0
# 7               738        21            6    5611  2000        0
# 8               745        13            5    4780  2000        0
# 9               762        15            9    6161  2000        0
# 10              707         5            3    4992  2000        0
# 11              621        15            6    7427  2000        0
# 12              649        14            3    3573  2000        0
# ...

# %%
mortdefault[1]
# Out:
#         creditScore  houseAge  yearsEmploy  ccDebt  year  default
# 0               739        23            5    5448  2001        0
# 1               778        23            5    8254  2001        0
# 2               653        22            4    5879  2001        0
# 3               701        22            7    4181  2001        0
# 4               580        11            7    6370  2001        0
# 5               600        16            4    2338  2001        0
# 6               703        20            7    2734  2001        0
# 7               723        35            6       0  2001        0
# 8               692        22            7    5926  2001        0
# 9               676        19            6    3565  2001        0
# 10              699        26            6    7607  2001        0
# 11              712        26            6    5503  2001        0
# 12              746        19            8    3633  2001        0
# ...

# %%
mortdefault2=pd.DataFrame(mortdefault)

# %%
mortdefault2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
# 0    10 non-null object
# dtypes: object(1)
# memory usage: 160.0+ bytes

# %%
mortdefault2
# Out:
#                                                    0
# 0          creditScore  houseAge  yearsEmploy  cc...
# 1          creditScore  houseAge  yearsEmploy  cc...
# 2          creditScore  houseAge  yearsEmploy  cc...
# 3          creditScore  houseAge  yearsEmploy  cc...
# 4          creditScore  houseAge  yearsEmploy  cc...
# 5          creditScore  houseAge  yearsEmploy  cc...
# 6          creditScore  houseAge  yearsEmploy  cc...
# 7          creditScore  houseAge  yearsEmploy  cc...
# 8          creditScore  houseAge  yearsEmploy  cc...
# 9          creditScore  houseAge  yearsEmploy  cc...

# %%
mort=pd.concat([mortdefault[0],mortdefault[1],mortdefault[2],mortdefault[3],mortdefault[4],mortdefault[5],mortdefault[6],mortdefault[7],mortdefault[8],mortdefault[9]], ignore_index= True)

# %%
mort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 6 columns):
# creditScore    int64
# houseAge       int64
# yearsEmploy    int64
# ccDebt         int64
# year           int64
# default        int64
# dtypes: int64(6)
# memory usage: 457.8 MB

# %%
mortdefaul22=mortdefault[0].append(mortdefault[1])

# %%
mortdefaul22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000000 entries, 0 to 999999
# Data columns (total 6 columns):
# creditScore    int64
# houseAge       int64
# yearsEmploy    int64
# ccDebt         int64
# year           int64
# default        int64
# dtypes: int64(6)
# memory usage: 106.8 MB

# %%
mort11=pd.concat(mortdefault,ignore_index=True)

# %%
mort11
# Out:
#          creditScore  houseAge  yearsEmploy  ccDebt  year  default
# 0                615        10            5    2818  2000        0
# 1                780        34            5    3575  2000        0
# 2                735        12            1    3184  2000        0
# 3                713        15            5    6236  2000        0
# 4                689        10            5    6817  2000        0
# 5                713        13            3    3646  2000        0
# 6                749        30            7    8056  2000        0
# 7                738        21            6    5611  2000        0
# 8                745        13            5    4780  2000        0
# 9                762        15            9    6161  2000        0
# 10               707         5            3    4992  2000        0
# 11               621        15            6    7427  2000        0
# 12               649        14            3    3573  2000        0
# ...
